# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sn
# %matplotlib inline

# %%
train=pd.read_csv("train.csv")
train_labels = pd.read_csv("train_labels.csv")
test=pd.read_csv("test.csv")
specs=pd.read_csv("specs.csv")
sample_submission =pd.read_csv("sample_submission.csv")

# %%
train.shape,train_labels.shape,test.shape,specs.shape,sample_submission.shape
# Out:
# ((11341042, 11), (17690, 7), (1156414, 11), (386, 3), (1000, 2))

# %%
for k in train.columns:
    print(k,train[k].nunique())
    
train.head()
# Out:
# event_id 384
# game_session 303319
# timestamp 10777308
# event_data 10893749
# installation_id 17000
# event_count 3368
# event_code 42
# game_time 834048
# title 44
# type 4
# world 4
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
# ...

# %%
for k in specs.columns:
    print(k,specs[k].nunique())
    
specs.head()
# Out:
# event_id 386
# info 168
# args 191
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %%
train.query('game_session == "45bb1e1b6b50c07b"')
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
#
#                                event_data installation_id  event_count  \
# 0  {"event_code": 2000, "event_count": 1}        0001e90f            1
#
#    event_code  game_time                    title  type world
# 0        2000          0  Welcome to Lost Lagoon!  Clip  NONE

# %%
train.groupby('game_session').size().nlargest(5)
# Out:
# game_session
# 6e6e697f2e593de1    3368
# bb1f09ec062b6660    3182
# 33495c8f126e2ef9    2505
# 34c82b23355e378c    2456
# 8fe0ab3c3e448a04    2398
# dtype: int64

# %%
train.query('game_session == "8fe0ab3c3e448a04"').head()
# Out:
#          event_id      game_session                 timestamp  \
# 6836702  d2278a3b  8fe0ab3c3e448a04  2019-08-12T17:24:05.473Z
# 6836703  b7530680  8fe0ab3c3e448a04  2019-08-12T17:24:05.740Z
# 6836704  67439901  8fe0ab3c3e448a04  2019-08-12T17:24:08.150Z
# 6836705  bb3e370b  8fe0ab3c3e448a04  2019-08-12T17:24:21.671Z
# 6836706  67439901  8fe0ab3c3e448a04  2019-08-12T17:24:22.684Z
#
#                                                 event_data installation_id  \
# 6836702  {"version":"1.0","round":0,"event_count":1,"ga...        994491d0
# 6836703  {"previous_jars":[],"round":1,"event_count":2,...        994491d0
# 6836704  {"description":"Hello! Today, we're making san...        994491d0
# 6836705  {"bottle":{"amount":1,"color":"green"},"bottle...        994491d0
# 6836706  {"description":"Look at it go! idle","identifi...        994491d0
#
#          event_count  event_code  game_time                     title  \
# ...

# %%
train.query('game_session == "8fe0ab3c3e448a04" or type == "Assessment"').head()

# %%
train['world'].unique()
# Out:
# array(['NONE', 'MAGMAPEAK', 'TREETOPCITY', 'CRYSTALCAVES'], dtype=object)

# %%
train['type'].unique()
# Out:
# array(['Clip', 'Activity', 'Game', 'Assessment'], dtype=object)

# %%
train_labels.head(15)
# Out:
#         game_session installation_id                         title  \
# 0   6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1   77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2   901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3   9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4   a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# 5   197a373a77101924        0006c192  Cauldron Filler (Assessment)
# 6   957406a905d59afd        0006c192    Bird Measurer (Assessment)
# 7   b2297d292892745a        0006c192  Mushroom Sorter (Assessment)
# 8   ae691ec5ad5652cf        00129856    Bird Measurer (Assessment)
# 9   7b536271e99518f0        001d0ed0    Bird Measurer (Assessment)
# 10  8fdd5d389d0e272e        001d0ed0     Chest Sorter (Assessment)
# 11  9480b026e3e7d371        001d0ed0    Cart Balancer (Assessment)
# 12  c046a858e7c8bf03        001d0ed0  Mushroom Sorter (Assessment)
# ...

# %%
train_labels['title'].unique()
# Out:
# array(['Mushroom Sorter (Assessment)', 'Bird Measurer (Assessment)',
#        'Cauldron Filler (Assessment)', 'Chest Sorter (Assessment)',
#        'Cart Balancer (Assessment)'], dtype=object)

# %%
test.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1  27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2  27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3  27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4  7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        00abaee7
# 1             {"event_code": 2000, "event_count": 1}        00abaee7
# 2             {"event_code": 2000, "event_count": 1}        00abaee7
# 3             {"event_code": 2000, "event_count": 1}        00abaee7
# 4  {"version":"1.0","round":0,"event_count":1,"ga...        00abaee7
#
#    event_count  event_code  game_time                    title  type  \
# 0            1        2000          0  Welcome to Lost Lagoon!  Clip
# 1            1        2000          0     Magma Peak - Level 1  Clip
# ...

# %%
train.groupby('type').head()
# Out:
#       event_id      game_session                 timestamp  \
# 0     27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1     27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2     77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3     b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4     1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# 5     1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.279Z
# 6     1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.913Z
# 362   6d90d394  f11eb823348bfa23  2019-09-06T18:00:51.915Z
# 363   7040c096  f11eb823348bfa23  2019-09-06T18:00:56.121Z
# 364   5a848010  f11eb823348bfa23  2019-09-06T18:00:57.986Z
# 365   4a09ace1  f11eb823348bfa23  2019-09-06T18:01:11.792Z
# 366   dcaede90  f11eb823348bfa23  2019-09-06T18:01:13.792Z
# 1103  27253bdc  091587ed87b9637c  2019-09-06T18:10:51.183Z
# 1355  27253bdc  3fce4f09769ff0b7  2019-09-06T18:18:11.250Z
# 1356  27253bdc  04168b61c0650977  2019-09-06T18:18:42.392Z
# ...

# %%
train.query('installation_id== "0006a69f" and type == "Assessment" and game_session=="901acc108f55a5a1" and event_code =="4100"')
# Out:
#       event_id      game_session                 timestamp  \
# 2228  25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
#
#                                              event_data installation_id  \
# 2228  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
#
#       event_count  event_code  game_time                         title  \
# 2228           44        4100      31011  Mushroom Sorter (Assessment)
#
#             type        world
# 2228  Assessment  TREETOPCITY

# %%
train_labels.query('installation_id== "0006a69f" and game_session =="901acc108f55a5a1"')
# Out:
#        game_session installation_id                         title  \
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 2            1              0       1.0               3

# %%
train_labels.query('installation_id== "0006a69f"')
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
train.query('installation_id== "0006a69f" and type == "Assessment" and game_session=="77b8ee947eb84b4e" and event_code =="4110"')
# Out:
#       event_id      game_session                 timestamp  \
# 2709  17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 2715  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 2720  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 2725  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# 2730  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:13.951Z
# 2733  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:17.407Z
# 2738  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:21.390Z
# 2743  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:26.296Z
# 2750  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:32.187Z
# 2756  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:38.140Z
# 2765  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:49.155Z
#
#                                              event_data installation_id  \
# 2709  {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 2715  {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# ...

# %%
check =train.query('installation_id== "0006a69f" and type == "Assessment" and game_session=="9501794defd84e4d" and event_code =="4100"')

# %%
check['event_data']
# Out:
# 3725    {"correct":false,"stumps":[3,2,5],"event_count":29,"game_time":18484,"event_code":4100}
# 3734    {"correct":true,"stumps":[2,3,5],"event_count":38,"game_time":23043,"event_code":4100}
# Name: event_data, dtype: object

# %%
che ="{"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":22,"game_time":22737,"event_code":4100}"
# Out:
#   File "<ipython-input-79-81dfafa5f463>", line 1
#     che ="{"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":22,"game_time":22737,"event_code":4100}"
#                   ^
# SyntaxError: invalid syntax

# %%
che
# Out:
# '{"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":22,"game_time":22737,"event_code":4100}'

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
from pandas.io.json import json_normalize
flat = flatten_json(che)
pd.set_option('display.max_colwidth', -1)
json_normalize(flat)
# Out:
#
# 0  {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":22,"game_time":22737,"event_code":4100}

# %%
import io
from pandas.io.json import json_normalize

# Loading the json string into a structure
json_dict = json.load(io.StringIO(json_str))

df = pd.concat([pd.DataFrame(json_dict), 
                json_normalize(json_dict['nested_array_to_expand'])], 
                axis=1).drop('nested_array_to_expand', 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-3c3508bb71ae> in <module>()
#       3
#       4 # Loading the json string into a structure
# ----> 5 json_dict = {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":22,"game_time":22737,"event_code":4100}
#       6
#       7 df = pd.concat([pd.DataFrame(json_dict),
#
# NameError: name 'true' is not defined

# %%
import json
extracted_event_data = pd.io.json.json_normalize(train.event_data.apply(json.loads))

# %%
#Test data analysis
test.groupby('game_session').size().nlargest(5)
# Out:
# game_session
# b246933e8ac6a4aa    4456
# b535012a46aceefc    3206
# 36c2efec95389982    1937
# f92482c02ea604a1    1362
# 5c4c1bae907d5572    1245
# dtype: int64

# %%
#test.query('game_session=="36c2efec95389982"')
test.query('type == "Assessment"').head()
#installation_id== "0006a69f" and type == "Assessment" and  event_code =="4100"
# Out:
#          event_id      game_session                 timestamp  \
# 282      7ad3efc6  8b38fc0d2fd315dc  2019-09-11T18:56:11.918Z
# 283      65a38bf7  8b38fc0d2fd315dc  2019-09-11T18:56:12.019Z
# 284      795e4a37  8b38fc0d2fd315dc  2019-09-11T18:56:12.030Z
# 285      5e109ec3  8b38fc0d2fd315dc  2019-09-11T18:56:15.790Z
# 286      5c2f29ca  8b38fc0d2fd315dc  2019-09-11T18:56:17.869Z
# 287      828e68f9  8b38fc0d2fd315dc  2019-09-11T18:56:19.084Z
# 288      5e109ec3  8b38fc0d2fd315dc  2019-09-11T18:56:19.155Z
# 289      5c2f29ca  8b38fc0d2fd315dc  2019-09-11T18:56:19.783Z
# 290      acf5c23f  8b38fc0d2fd315dc  2019-09-11T18:56:23.168Z
# 291      acf5c23f  8b38fc0d2fd315dc  2019-09-11T18:56:23.184Z
# 292      acf5c23f  8b38fc0d2fd315dc  2019-09-11T18:56:24.450Z
# 293      5e109ec3  8b38fc0d2fd315dc  2019-09-11T18:56:24.611Z
# 294      3d63345e  8b38fc0d2fd315dc  2019-09-11T18:56:26.200Z
# 295      acf5c23f  8b38fc0d2fd315dc  2019-09-11T18:56:26.815Z
# ...

# %%
test.query('installation_id== "00abaee7" and type == "Assessment" and game_session=="8b38fc0d2fd315dc" and event_code =="4100"')
# Out:
#      event_id      game_session                 timestamp  \
# 303  d122731b  8b38fc0d2fd315dc  2019-09-11T18:56:34.661Z
#
#                                                                                                                                                                                            event_data  \
# 303  {"correct":true,"left":[{"id":"gem07","weight":6},{"id":"gem05","weight":4}],"right":[{"id":"gem08","weight":6},{"id":"gem06","weight":4}],"event_count":22,"game_time":22737,"event_code":4100}
#
#     installation_id  event_count  event_code  game_time  \
# 303  00abaee7        22           4100        22737
#
#                           title        type         world
# 303  Cart Balancer (Assessment)  Assessment  CRYSTALCAVES

# %%
sample_submission.query('installation_id== "00abaee7"')
# Out:
#   installation_id  accuracy_group
# 0  00abaee7        3

# %%
sample_submission['accuracy_group'].unique()
# Out:
# array([3], dtype=int64)
